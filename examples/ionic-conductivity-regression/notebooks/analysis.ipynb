# %% [markdown]
# # Ionic Conductivity Regression
#
# Use the agent queue to prepare a regression notebook, then run the cells locally.

# %%
import pandas as pd
from pathlib import Path

df = pd.read_csv(Path.cwd() / "data/raw/ionic_conductivity_screen.csv")
df.head()
